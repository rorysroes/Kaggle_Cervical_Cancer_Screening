# %%
import os
import cv2
import glob
from glob import glob
import math
import numpy as np
import pandas as pd
import tensorflow as tf
import keras
import matplotlib.pyplot
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from multiprocessing import Pool, cpu_count
from PIL import ImageFilter, ImageStat, Image, ImageDraw
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from IPython.display import display
from collections import defaultdict
# Out:
# Using TensorFlow backend.

# %%
def show(X):
    display(Image.fromarray(X))

# %%
train_data = np.load('/home/Kaggle_Cervical_Cancer_Screening/Rory/Dev-ipynb/resize_data/ALL_TRAIN_SEGPA_10_64.npy')
test_data = np.load('/home/Kaggle_Cervical_Cancer_Screening/Rory/Dev-ipynb/resize_data/ALL_TEST_SEGPA_10_64.npy')
train = pd.read_csv('/home/Kaggle_Cervical_Cancer_Screening/Rory/Dev-ipynb/resize_data/TRAIN.csv')
test = pd.read_csv('/home/Kaggle_Cervical_Cancer_Screening/Rory/Dev-ipynb/resize_data/TEST.csv')
test_id = test.image.values

# %%
test_stg2 = pd.read_csv('/home/Kaggle_Cervical_Cancer_Screening/Rory/Dev-ipynb/TEST_STG2.csv')
test_stg2_data = np.load('/home/Kaggle_Cervical_Cancer_Screening/Rory/Dev-ipynb/ALL_TEST_STG2_SEGPA_80_64.npy')
test_stg2_id = test_stg2.image.values

# %%
show(train_data[900])
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7FF53833BEF0>

# %%
train_data_ud = train_data[:,::-1,:,:]

# %%
show(train_data_ud[900])
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7FF576958EF0>

# %%
train_data_rl = train_data[:,:,::-1,:]

# %%
show(train_data_rl[900])
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7FF53833B908>

# %%
def rotation(image, angle):
    assert image.shape[-1] == 3
    num_rows, num_cols = image.shape[:2]
    rotation_matrix = cv2.getRotationMatrix2D((num_cols/2, num_rows/2), angle, 1)
    img_rotation = cv2.warpAffine(image, rotation_matrix, (num_cols, num_rows))
    return img_rotation

# %%
rot_num = 12
rot_imgs = defaultdict(list)
for i in range(train_data.shape[0]):
    for rot in range(int(360/rot_num),360,int(360/rot_num)):
        rot_img = rotation(train_data[i,:,:,:], rot)
        rot_imgs[rot].append(rot_img)

# %%
show(rot_imgs[30][900])
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7FF57697A518>

# %%
show(rot_imgs[120][900])
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7FF57697A668>

# %%
show(rot_imgs[330][900])
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7FF57697A3C8>

# %%
train_data = np.concatenate([train_data, train_data_ud, train_data_rl,\
                             np.array(rot_imgs[30]),np.array(rot_imgs[60]),\
                             np.array(rot_imgs[90]),np.array(rot_imgs[120]),\
                             np.array(rot_imgs[150]),np.array(rot_imgs[180]),\
                             np.array(rot_imgs[210]),np.array(rot_imgs[240]),\
                             np.array(rot_imgs[270]),np.array(rot_imgs[300]),\
                             np.array(rot_imgs[330])])

# %%
train_data.shape
# Out:
# (114968, 64, 64, 3)

# %% [markdown]
# ### 增加亮度

# %%
train_data_light = (train_data * 1.2).clip(0,255).astype(np.uint8)

# %%
train_data_light.shape
# Out:
# (114968, 64, 64, 3)

# %%
show(train_data_light[800])
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7FF57697A940>

# %% [markdown]
# ### 減少亮度

# %%
train_data_non_light = (train_data * 0.8).clip(0,255).astype(np.uint8)

# %%
train_data_non_light.shape
# Out:
# (114968, 64, 64, 3)

# %%
show(train_data_non_light[800])
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7FF57697AC50>

# %% [markdown]
# ### 組合

# %%
train_X = np.concatenate([train_data,train_data_light,train_data_non_light])

# %%
train_X.shape
# Out:
# (344904, 64, 64, 3)

# %%
le = LabelEncoder()
train_target = le.fit_transform(train['type'].values)
train_Y = np.concatenate([train_target for i in range(14*3)])

# %%
train_X.shape, train_Y.shape
# Out:
# ((344904, 64, 64, 3), (344904,))

# %%
random_index = np.random.choice(range(train_X.shape[0]), train_X.shape[0], replace = False)

# %%
train_X = train_X[random_index]
train_Y = train_Y[random_index]

# %%
show(train_X[800])
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7FF57697ADA0>

# %%
x_train, x_val_train, y_train, y_val_train =\
train_test_split(train_X, train_Y, test_size = 0.3, random_state=17)

# %%
x_train.shape, x_val_train.shape, y_train.shape, y_val_train.shape
# Out:
# ((241432, 64, 64, 3), (103472, 64, 64, 3), (241432,), (103472,))

# %%
train_X.shape
# Out:
# (344904, 64, 64, 3)

# %%
#%timeit np.save('/home/Kaggle_Cervical_Cancer_Screening/Image_Data/Data_NOSEG_30W_Feature.npy', train_X)

# %%
#%timeit np.save('/home/Kaggle_Cervical_Cancer_Screening/Image_Data/Data_NOSEG_30W_Label.npy', train_Y)

# %%
# 3種 Type
num_classes = 3
y_train = keras.utils.to_categorical(y_train, num_classes)
y_val_train = keras.utils.to_categorical(y_val_train, num_classes)

# %%
from keras.layers import Dense, Activation, Conv2D, MaxPool2D, Reshape
from keras.wrappers.scikit_learn import KerasClassifier
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Flatten, Activation
from keras.layers.convolutional import Convolution2D, ZeroPadding2D, MaxPooling2D
from keras import optimizers
from keras import backend as K

# %%
model = Sequential()
model.add(Reshape((64,64,3), input_shape = x_train.shape[1:]))
model.add(Conv2D(16, (3, 3), padding='same',data_format = "channels_last"))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size = (2, 2), data_format = "channels_last"))
model.add(Dropout(0.2))

model.add(Conv2D(16, (3, 3), padding='same',  data_format = "channels_last"))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size = (2, 2), data_format = "channels_last"))
model.add(Dropout(0.2))

model.add(Flatten())
model.add(Dense(12))
model.add(Activation('tanh'))
model.add(Dropout(0.1))
model.add(Dense(num_classes))
model.add(Activation('softmax'))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_2 (Reshape)          (None, 64, 64, 3)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 64, 64, 16)        448
# _________________________________________________________________
# activation_5 (Activation)    (None, 64, 64, 16)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 32, 32, 16)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 16)        2320
# _________________________________________________________________
# activation_6 (Activation)    (None, 32, 32, 16)        0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 16, 16, 16)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 16, 16, 16)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 12)                49164
# _________________________________________________________________
# activation_7 (Activation)    (None, 12)                0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 12)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 39
# _________________________________________________________________
# activation_8 (Activation)    (None, 3)                 0
# =================================================================
# Total params: 51,971
# Trainable params: 51,971
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
x_train = x_train.astype('float32')
x_val_train = x_val_train.astype('float32')

x_train /= 255
x_val_train /= 255

x_test = test_data.astype('float32')
x_test /= 255

# %%
x_test_stg2= test_stg2_data.astype('float32')
x_test_stg2 /= 255

# %%
model.fit(x_train, y_train, validation_data = (x_val_train, y_val_train), epochs = 10, batch_size = 128)
# Out:
# Train on 241432 samples, validate on 103472 samples
# Epoch 1/10
# 241432/241432 [==============================] - 54s - loss: 0.9598 - acc: 0.5316 - val_loss: 0.9533 - val_acc: 0.5380
# Epoch 2/10
# 241432/241432 [==============================] - 48s - loss: 0.9344 - acc: 0.5399 - val_loss: 0.9260 - val_acc: 0.5421
# Epoch 3/10
#  - ETA: 6s - loss: 0.9166 - acc: 0.5480
# Epoch 4/10
#  - ETA: 2s - loss: 0.9030 - acc: 0.5558
# Epoch 5/10
#  - ETA: 13s - loss: 0.8929 - acc: 0.5629
# Epoch 6/10
#  - ETA: 1s - loss: 0.8802 - acc: 0.5715
# Epoch 7/10
#  - ETA: 2s - loss: 0.8726 - acc: 0.5763
# Epoch 8/10
#  - ETA: 1s - loss: 0.8642 - acc: 0.5821
# Epoch 9/10
# 241432/241432 [==============================] - 48s - loss: 0.8572 - acc: 0.5868 - val_loss: 0.8420 - val_acc: 0.5953
# Epoch 10/10
#  - ETA: 20s - loss: 0.8506 - acc: 0.5894

# %%
pred = model.predict_proba(x_test)
# Out:
# 480/512 [===========================>..] - ETA: 0s

# %%
df = pd.DataFrame(pred, columns=['Type_1','Type_2','Type_3'])
df['image_name'] = test_id
df = df[['image_name','Type_1','Type_2','Type_3']]

# %%
sample_submission =\
pd.read_csv('/home/Kaggle_Cervical_Cancer_Screening/submission/sample_submission.csv')

# %%
for name in sample_submission['image_name']:
    #print(name)
    #sub[name] = df[df['image_name'] == name][['Type_1','Type_2','Type_3']].values.tolist()[0]
    #print(name)
    Type_1 = df.loc[df['image_name'] == name, 'Type_1']
    Type_2 = df.loc[df['image_name'] == name, 'Type_2']
    Type_3 = df.loc[df['image_name'] == name, 'Type_3']
    
    Type_1_index = Type_1.index[0]
    Type_2_index = Type_2.index[0]
    Type_3_index = Type_3.index[0]
    
    sample_submission.loc[sample_submission['image_name'] == name, 'Type_1'] = Type_1[Type_1_index]
    
    sample_submission.loc[sample_submission['image_name'] == name, 'Type_2'] = Type_2[Type_2_index]
    
    sample_submission.loc[sample_submission['image_name'] == name, 'Type_3'] = Type_3[Type_3_index]

# %%
sample_submission.head()
# Out:
#   image_name    Type_1    Type_2    Type_3
# 0      0.jpg  0.252477  0.645934  0.101589
# 1      1.jpg  0.056681  0.498497  0.444822
# 2      2.jpg  0.140104  0.643336  0.216560
# 3      3.jpg  0.088470  0.414894  0.496636
# 4      4.jpg  0.105964  0.453218  0.440818

# %%
True_outcome = pd.read_csv('/home/dataset/solution_stg1_release.csv')

# %%
True_outcome.head()
# Out:
#   image_name  Type_1  Type_2  Type_3
# 0      0.jpg       0       1       0
# 1      1.jpg       0       1       0
# 2      2.jpg       1       0       0
# 3      3.jpg       0       0       1
# 4      4.jpg       0       0       1

# %%
Pred = sample_submission[["Type_1","Type_2","Type_3"]].values

# %%
Ober = True_outcome[["Type_1","Type_2","Type_3"]].values

# %%
func = lambda y, p: y * np.log(max(min(p, 1-10e-15),10e-15))
log_loss = 0.0
for i in range(0, sample_submission.shape[0], 1):

    log_loss += np.sum(np.array(list(map(func, Ober[i], Pred[i]))))
    #print(log_loss)
log_loss /= (-1.) * sample_submission.shape[0]

# %%
log_loss
# Out:
# 0.87350936354778241

# %%
pred_stg2 = model.predict_proba(x_test_stg2)
df_stg2 = pd.DataFrame(pred_stg2, columns=['Type_1','Type_2','Type_3'])
df_stg2['image_name'] = test_stg2_id
df_stg2 = df_stg2[['image_name','Type_1','Type_2','Type_3']]
# Out:
# 3424/3506 [============================>.] - ETA: 0s

# %%
df_stg2.head()
# Out:
#   image_name    Type_1    Type_2    Type_3
# 0  12708.jpg  0.078167  0.411217  0.510616
# 1  13284.jpg  0.082666  0.494170  0.423164
# 2  11551.jpg  0.072247  0.545988  0.381765
# 3  11151.jpg  0.074703  0.729976  0.195321
# 4  11643.jpg  0.150060  0.724047  0.125893

# %%
df_stg2.shape
# Out:
# (3506, 4)

# %%
df_stg2_submission = pd.concat([sample_submission, df_stg2]).reset_index(drop=True)

# %%
df_stg2_submission.to_csv('/home/Kaggle_Cervical_Cancer_Screening/submission/submission_SEGPA_10_01_stg2.csv', index=False)

# %% [markdown]
# ### Ensemble

# %%
df_stg2_submission01 = pd.read_csv("/home/Kaggle_Cervical_Cancer_Screening/submission/submission_SEGPA_10_01_stg2.csv")

# %%
df_stg2_submission02 = pd.read_csv("/home/Kaggle_Cervical_Cancer_Screening/submission/submission_SEG01_stg2.csv")

# %%
# 504    504.jpg  0.002675  0.228898  7.684268e-01
# 505    505.jpg  0.000052  0.978979  2.096925e-02
# 506    506.jpg  0.000055  0.538606  4.613385e-01
# 507    507.jpg  0.001181  0.908610  9.020925e-02
# 508    508.jpg  0.000590  0.994856  4.554756e-03
# 509    509.jpg  0.005370  0.965269  2.936096e-02
# 510    510.jpg  0.000597  0.264350  7.350530e-01
# 511    511.jpg  0.000281  0.681964  3.177551e-01
#
# [512 rows x 4 columns]

# %%
True_outcome
# Out:
#     image_name  Type_1  Type_2  Type_3
# 0        0.jpg       0       1       0
# 1        1.jpg       0       1       0
# 2        2.jpg       1       0       0
# 3        3.jpg       0       0       1
# 4        4.jpg       0       0       1
# 5        5.jpg       0       1       0
# 6        6.jpg       0       1       0
# 7        7.jpg       0       1       0
# 8        8.jpg       0       1       0
# 9        9.jpg       0       1       0
# 10      10.jpg       0       1       0
# 11      11.jpg       0       0       1
# 12      12.jpg       0       1       0
# 13      13.jpg       0       0       1
# 14      14.jpg       0       1       0
# 15      15.jpg       0       0       1
# 16      16.jpg       1       0       0
# 17      17.jpg       0       1       0
# 18      18.jpg       0       1       0
# 19      19.jpg       0       0       1
# 20      20.jpg       1       0       0
# 21      21.jpg       0       1       0
# 22      22.jpg       0       1       0
# 23      23.jpg       1       0       0
# 24      24.jpg       0       1       0
# 25      25.jpg       1       0       0
# 26      26.jpg       0       1       0
# 27      27.jpg       0       0       1
# 28      28.jpg       0       1       0
# 29      29.jpg       0       0       1
# ..         ...     ...     ...     ...
# 482    482.jpg       1       0       0
# 483    483.jpg       0       1       0
# 484    484.jpg       0       0       1
# 485    485.jpg       0       0       1
# 486    486.jpg       0       1       0
# 487    487.jpg       0       1       0
# 488    488.jpg       0       1       0
# 489    489.jpg       1       0       0
# 490    490.jpg       0       1       0
# 491    491.jpg       0       0       1
# 492    492.jpg       0       1       0
# 493    493.jpg       1       0       0
# 494    494.jpg       0       1       0
# 495    495.jpg       0       1       0
# 496    496.jpg       0       0       1
# 497    497.jpg       0       1       0
# 498    498.jpg       0       1       0
# 499    499.jpg       0       0       1
# 500    500.jpg       0       1       0
# 501    501.jpg       0       1       0
# 502    502.jpg       0       0       1
# 503    503.jpg       0       1       0
# 504    504.jpg       0       0       1
# 505    505.jpg       0       1       0
# 506    506.jpg       0       1       0
# 507    507.jpg       0       1       0
# 508    508.jpg       0       1       0
# 509    509.jpg       0       1       0
# 510    510.jpg       0       1       0
# 511    511.jpg       0       0       1
#
# [512 rows x 4 columns]

# %%
df_ensemble = df_stg2_submission02
df_ensemble[['Type_1']] = (df_stg2_submission01[['Type_1']] + df_stg2_submission02[['Type_1']]) * 0.5
df_ensemble[['Type_2']] = (df_stg2_submission01[['Type_2']] + df_stg2_submission02[['Type_2']]) * 0.5
df_ensemble[['Type_3']] = (df_stg2_submission01[['Type_3']] + df_stg2_submission02[['Type_3']]) * 0.5

# %%
df_ensemble[['Type_1','Type_2','Type_3']].div(df_ensemble[['Type_1','Type_2','Type_3']].sum(axis=1), axis=0)
# Out:
#         Type_1    Type_2    Type_3
# 0     0.129956  0.817852  0.052192
# 1     0.028722  0.293030  0.678248
# 2     0.569461  0.322251  0.108288
# 3     0.044317  0.600861  0.354822
# 4     0.053023  0.232327  0.714649
# 5     0.277089  0.712160  0.010751
# 6     0.248126  0.719064  0.032810
# 7     0.160410  0.290975  0.548615
# 8     0.029042  0.700806  0.270152
# 9     0.173832  0.782119  0.044049
# 10    0.361666  0.589922  0.048412
# 11    0.029005  0.179190  0.791805
# 12    0.075751  0.217889  0.706360
# 13    0.106800  0.440350  0.452849
# 14    0.011231  0.715133  0.273636
# 15    0.061115  0.239026  0.699858
# 16    0.023645  0.654648  0.321707
# 17    0.394424  0.520511  0.085064
# 18    0.392794  0.585118  0.022089
# 19    0.034919  0.305339  0.659742
# 20    0.696149  0.288397  0.015455
# 21    0.189628  0.779538  0.030834
# 22    0.106273  0.759805  0.133922
# 23    0.362887  0.360195  0.276919
# 24    0.125565  0.785764  0.088671
# 25    0.112335  0.763332  0.124333
# 26    0.107765  0.856977  0.035257
# 27    0.092500  0.513287  0.394212
# 28    0.334883  0.575635  0.089482
# 29    0.087619  0.763877  0.148505
# ...        ...       ...       ...
# 3988  0.943472  0.041485  0.015043
# 3989  0.085218  0.765253  0.149529
# 3990  0.907147  0.075302  0.017551
# 3991  0.122135  0.816204  0.061660
# 3992  0.121948  0.223412  0.654641
# 3993  0.033536  0.763881  0.202583
# 3994  0.627905  0.290665  0.081430
# 3995  0.060344  0.370417  0.569239
# 3996  0.147312  0.471351  0.381337
# 3997  0.034846  0.263546  0.701608
# 3998  0.025149  0.689973  0.284879
# 3999  0.025529  0.808304  0.166168
# 4000  0.129175  0.708864  0.161961
# 4001  0.150965  0.822401  0.026635
# 4002  0.034093  0.799356  0.166551
# 4003  0.046936  0.563359  0.389705
# 4004  0.094550  0.850541  0.054909
# 4005  0.086433  0.397987  0.515580
# 4006  0.178920  0.434561  0.386519
# 4007  0.063635  0.809310  0.127055
# 4008  0.136614  0.316466  0.546920
# 4009  0.050437  0.824858  0.124704
# 4010  0.468713  0.526985  0.004302
# 4011  0.300777  0.683895  0.015328
# 4012  0.065512  0.766049  0.168438
# 4013  0.123539  0.240658  0.635803
# 4014  0.084410  0.742239  0.173351
# 4015  0.092750  0.867181  0.040069
# 4016  0.161572  0.792484  0.045944
# 4017  0.093016  0.371818  0.535166
#
# [4018 rows x 3 columns]

# %%
df_ensemble.head()
# Out:
#   image_name    Type_1    Type_2    Type_3
# 0      0.jpg  0.129956  0.817851  0.052192
# 1      1.jpg  0.028722  0.293030  0.678248
# 2      2.jpg  0.569461  0.322251  0.108288
# 3      3.jpg  0.044317  0.600861  0.354822
# 4      4.jpg  0.053023  0.232327  0.714649

# %%
Pred = df_ensemble[["Type_1","Type_2","Type_3"]].values

# %%
True_outcome = pd.read_csv('/home/dataset/solution_stg1_release.csv')

# %%
func = lambda y, p: y * np.log(max(min(p, 1-10e-15),10e-15))
log_loss = 0.0
for i in range(0, sample_submission.shape[0], 1):

    log_loss += np.sum(np.array(list(map(func, Ober[i], Pred[i]))))
    #print(log_loss)
log_loss /= (-1.) * sample_submission.shape[0]

# %%
log_loss
# Out:
# 0.7924255777648328

# %%
df_ensemble.to_csv('/home/Kaggle_Cervical_Cancer_Screening/submission/submission_SE_NO_GPA_10_stg2.csv', index=False)
