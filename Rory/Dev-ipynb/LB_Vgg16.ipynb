# %%
import keras
from keras.models import Sequential
from PIL import Image
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
import pandas as pd

# %%
import keras.backend as K
K.set_image_data_format('channels_last')

# %%
base_model = keras.applications.vgg16.VGG16(weights = 'imagenet',  include_top = False, input_shape=(64,64,3))

# %%
base_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 64, 64, 3)         0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 64, 64, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 64, 64, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 32, 32, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 32, 32, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 32, 32, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 16, 16, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 16, 16, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 8, 8, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 8, 8, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 2, 2, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.layers import GlobalAveragePooling2D, Dense
from keras.models import Model

_ = base_model.get_layer("block5_conv3").output
_ = GlobalAveragePooling2D()(_)
_ = Dense(512, activation='relu')(_)

# 3 個輸出
predictions = Dense(3, activation='softmax')(_)

# 這是我們的 model
model = Model(inputs=base_model.input, outputs=predictions)

# 將原來的模型設定成不可訓練，只訓練上面的兩層 dense layers
for layer in base_model.layers:
    layer.trainable = False

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 64, 64, 3)         0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 64, 64, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 64, 64, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 32, 32, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 32, 32, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 32, 32, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 16, 16, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 16, 16, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 8, 8, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 8, 8, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 1539
# =================================================================
# Total params: 14,978,883
# Trainable params: 264,195
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
train_data = np.load('/home/Kaggle_Cervical_Cancer_Screening/Rory/Dev-ipynb/resize_data/ALL_TRAIN_NOSEG_64.npy')

# %%
test_data = np.load('/home/Kaggle_Cervical_Cancer_Screening/Rory/Dev-ipynb/resize_data/ALL_TEST_NOSEG_64.npy')

# %%
train = pd.read_csv('/home/Kaggle_Cervical_Cancer_Screening/Rory/Dev-ipynb/resize_data/TRAIN.csv')
test = pd.read_csv('/home/Kaggle_Cervical_Cancer_Screening/Rory/Dev-ipynb/resize_data/TEST.csv')

# %%
test_id = test.image.values

# %%
le = LabelEncoder()
train_target = le.fit_transform(train['type'].values)

x_train, x_val_train, y_train, y_val_train =\
train_test_split(train_data, train_target, test_size = 0.4, random_state=17)

# %%
num_classes = 3
y_train = keras.utils.to_categorical(y_train, num_classes)
y_val_train = keras.utils.to_categorical(y_val_train, num_classes)

# %%
x_train = x_train.astype('float32')
x_val_train = x_val_train.astype('float32')

x_train /= 255
x_val_train /= 255

x_test = test_data.astype('float32')
x_test /= 255

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
# shift = 0.2
datagen = ImageDataGenerator(rotation_range = 180,\
                             horizontal_flip = True,\
                             vertical_flip = True,\
                             #width_shift_range=shift,\
                             #height_shift_range=shift,\
                             data_format = "channels_last")
datagen.fit(x_train)

# %%
model.fit_generator(datagen.flow(x_train, y_train,\
                                 batch_size = 64, shuffle = True),\
                    epochs = 30,\
                    steps_per_epoch = 500,\
                    verbose = 1,\
                    validation_data = (x_val_train, y_val_train))
# Out:
# Epoch 1/30
# 500/500 [==============================] - 56s - loss: 0.9450 - acc: 0.5411 - val_loss: 0.9524 - val_acc: 0.5370
# Epoch 2/30
#  - ETA: 28s - loss: 0.9120 - acc: 0.5588
# Epoch 3/30
#  - ETA: 20s - loss: 0.8874 - acc: 0.5705
# Epoch 4/30
#  - ETA: 0s - loss: 0.8572 - acc: 0.5915
# Epoch 5/30
#  - ETA: 26s - loss: 0.8390 - acc: 0.6004
# Epoch 6/30
# 500/500 [==============================] - 55s - loss: 0.8099 - acc: 0.6229 - val_loss: 0.9113 - val_acc: 0.5553
# Epoch 7/30
#  - ETA: 24s - loss: 0.8008 - acc: 0.6274
# Epoch 8/30
#  - ETA: 20s - loss: 0.7735 - acc: 0.6423
# Epoch 9/30
#  - ETA: 17s - loss: 0.7562 - acc: 0.6491
# Epoch 10/30
#  - ETA: 20s - loss: 0.7366 - acc: 0.6602
# Epoch 11/30
#  - ETA: 29s - loss: 0.7283 - acc: 0.6740
# Epoch 12/30
#  - ETA: 17s - loss: 0.7055 - acc: 0.6859
# Epoch 13/30
#  - ETA: 4s - loss: 0.6909 - acc: 0.6871
# Epoch 14/30
#  - ETA: 12s - loss: 0.6836 - acc: 0.6946
# Epoch 15/30
#  - ETA: 39s - loss: 0.6663 - acc: 0.7008
# Epoch 16/30
#  - ETA: 15s - loss: 0.6497 - acc: 0.7128
# Epoch 17/30
#  - ETA: 20s - loss: 0.6428 - acc: 0.7136
# Epoch 18/30
# 500/500 [==============================] - 55s - loss: 0.6248 - acc: 0.7230 - val_loss: 0.9500 - val_acc: 0.5881
# Epoch 19/30
#  - ETA: 4s - loss: 0.6203 - acc: 0.7237
# Epoch 20/30
#  - ETA: 18s - loss: 0.6034 - acc: 0.7292
# Epoch 21/30
#  - ETA: 32s - loss: 0.5977 - acc: 0.7384
# Epoch 22/30
# 500/500 [==============================] - 55s - loss: 0.5825 - acc: 0.7443 - val_loss: 0.9639 - val_acc: 0.5842
# Epoch 23/30
#  - ETA: 12s - loss: 0.5783 - acc: 0.7489
# Epoch 24/30
#  - ETA: 7s - loss: 0.5649 - acc: 0.7562
# Epoch 25/30
#  - ETA: 16s - loss: 0.5509 - acc: 0.7639
# Epoch 26/30
# 500/500 [==============================] - 54s - loss: 0.5509 - acc: 0.7610 - val_loss: 0.9983 - val_acc: 0.6006
# Epoch 27/30
#  - ETA: 33s - loss: 0.5443 - acc: 0.7658
# Epoch 28/30
#  - ETA: 1s - loss: 0.5302 - acc: 0.7708
# Epoch 29/30
#  - ETA: 35s - loss: 0.5269 - acc: 0.7743
# Epoch 30/30
# 500/500 [==============================] - 55s - loss: 0.5123 - acc: 0.7831 - val_loss: 1.0090 - val_acc: 0.6064

# %%
x_test.shape
# Out:
# (512, 64, 64, 3)

# %%
pred = model.predict(x_test)

# %%
pred.shape
# Out:
# (512, 3)

# %%
df = pd.DataFrame(pred, columns=['Type_1','Type_2','Type_3'])

# %%
df['image_name'] = test_id

# %%
df = df[['image_name','Type_1','Type_2','Type_3']]

# %%
df.to_csv('/home/Kaggle_Cervical_Cancer_Screening/submission/submission_LB_vgg16_1.csv', index=False)
