# %% [markdown]
# Public Leader-board of 0.89094
# ====================================================

# %% [markdown]
# Save train and test images to normalized numpy arrays once for running multiple neural network configuration tests

# %%
from PIL import ImageFilter, ImageStat, Image, ImageDraw
from multiprocessing import Pool, cpu_count
from sklearn.preprocessing import LabelEncoder
import pandas as pd
import numpy as np
import glob
import cv2
import time

# %%
def im_multi(path):
    try:
        im_stats_im_ = Image.open(path)
        return [path, {'size': im_stats_im_.size}]
#         im_stats_im_ = cv2.imread(path)
#         return [path, {"size": im_stats_im_.shape[:2]}]
    except:
#         print(path)
        print ("bad image: " + path)
        return [path, {'size': [0,0]}]

# %%
def im_stats(im_stats_df):
    im_stats_d = {}
    p = Pool(cpu_count())
    ret = p.map(im_multi, im_stats_df['path'])
    for i in range(len(ret)):
        im_stats_d[ret[i][0]] = ret[i][1]
    im_stats_df['size'] = im_stats_df['path'].map(lambda x: ' '.join(str(s) for s in im_stats_d[x]['size']))
    return im_stats_df

# %%
def get_im_cv2(path):
    img = cv2.imread(path)
    resized = cv2.resize(img, (32, 32), cv2.INTER_LINEAR) #use cv2.resize(img, (64, 64), cv2.INTER_LINEAR)
#     cv2.resize(img, (64, 64), cv2.INTER_LINEAR)
    
    return [path, resized]

# %%
def normalize_image_features(paths):
    imf_d = {}
    p = Pool(cpu_count())
    ret = p.map(get_im_cv2, paths)
    for i in range(len(ret)):
        imf_d[ret[i][0]] = ret[i][1]
    ret = []
    fdata = [imf_d[f] for f in paths]
    fdata = np.array(fdata, dtype=np.uint8)
    fdata = fdata.transpose((0, 3, 1, 2))
    fdata = fdata.astype('float32')
    fdata = fdata / 255
    return fdata

# %%
t1 = time.time()

train = glob.glob('/data/kaggle/train/**/*.jpg') + glob.glob('/data/kaggle/additional/**/*.jpg')
train = pd.DataFrame([[p.split('/')[4],p.split('/')[5],p] for p in train], columns = ['type','image','path'])[4::5] #limit for Kaggle Demo
train = im_stats(train)
train = train[train['size'] != '0 0'].reset_index(drop=True) #remove bad images
train_data = normalize_image_features(train['path'])

print("===", time.time() - t1, " sec spent===")
# Out:
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 524288 bytes but only got 0. Skipping tag 3
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 524288 bytes but only got 0. Skipping tag 3
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 393216 bytes but only got 0. Skipping tag 3
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 524288 bytes but only got 0. Skipping tag 3
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 33554432 bytes but only got 0. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 393216 bytes but only got 0. Skipping tag 3
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 524288 bytes but only got 0. Skipping tag 3
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 33554432 bytes but only got 0. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 25165824 bytes but only got 0. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 25165824 bytes but only got 0. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 393216 bytes but only got 0. Skipping tag 3
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 131072 bytes but only got 0. Skipping tag 3
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 524288 bytes but only got 0. Skipping tag 3
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 33554432 bytes but only got 0. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 131072 bytes but only got 0. Skipping tag 3
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 204865536 bytes but only got 0. Skipping tag 5
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 524288 bytes but only got 0. Skipping tag 3
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 393216 bytes but only got 0. Skipping tag 3
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 393216 bytes but only got 0. Skipping tag 3
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 524288 bytes but only got 0. Skipping tag 3
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 25165824 bytes but only got 0. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 205389824 bytes but only got 0. Skipping tag 5
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 33554432 bytes but only got 0. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 33554432 bytes but only got 0. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 393216 bytes but only got 0. Skipping tag 3
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 217972736 bytes but only got 0. Skipping tag 5
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 393216 bytes but only got 0. Skipping tag 3
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 131072 bytes but only got 0. Skipping tag 3
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 218497024 bytes but only got 0. Skipping tag 5
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 25165824 bytes but only got 0. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 495583232 bytes but only got 0. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 33554432 bytes but only got 0. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 33554432 bytes but only got 0. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 131072 bytes but only got 0. Skipping tag 3
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 25165824 bytes but only got 0. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 204996608 bytes but only got 0. Skipping tag 5
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 25165824 bytes but only got 0. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 25165824 bytes but only got 0. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 205914112 bytes but only got 10704. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 524288 bytes but only got 0. Skipping tag 3
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 205520896 bytes but only got 0. Skipping tag 5
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 131072 bytes but only got 0. Skipping tag 3
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 572391424 bytes but only got 0. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 217972736 bytes but only got 0. Skipping tag 5
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 131072 bytes but only got 0. Skipping tag 3
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 131072 bytes but only got 0. Skipping tag 3
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 480182272 bytes but only got 0. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 393216 bytes but only got 0. Skipping tag 3
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 217972736 bytes but only got 0. Skipping tag 5
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 3640590336 bytes but only got 0. Skipping tag 0
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 204865536 bytes but only got 0. Skipping tag 5
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 206045184 bytes but only got 10471. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 219021312 bytes but only got 12076. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 218497024 bytes but only got 0. Skipping tag 5
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 99877888 bytes but only got 0. Skipping tag 1029
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read
bytes but only got 0. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 205914112 bytes but only got 12030. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 205914112 bytes but only got 11438. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 750649344 bytes but only got 0. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 205914112 bytes but only got 11699. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 205914112 bytes but only got 14596. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 205914112 bytes but only got 10350. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 493748224 bytes but only got 0. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 205914112 bytes but only got 10676. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 501088256 bytes but only got 0. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 205914112 bytes but only got 10788. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 586285056 bytes but only got 0. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 744816640 bytes but only got 0. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 205914112 bytes but only got 14507. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 584056832 bytes but only got 0. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 205914112 bytes but only got 12088. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 205914112 bytes but only got 12054. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 417464320 bytes but only got 0. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 11090231504 bytes but only got 0. Skipping tag 54144
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 542965760 bytes but only got 0. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 205914112 bytes but only got 9512. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 205914112 bytes but only got 11427. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 565116928 bytes but only got 0. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 466485248 bytes but only got 0. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 10919258656 bytes but only got 0. Skipping tag 19181
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 644546560 bytes but only got 0. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 731185152 bytes but only got 0. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 536281088 bytes but only got 0. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 205914112 bytes but only got 10260. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 567083008 bytes but only got 0. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 205914112 bytes but only got 11765. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 205914112 bytes but only got 14299. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 205914112 bytes but only got 12977. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 205914112 bytes but only got 11795. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 536150016 bytes but only got 0. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 205914112 bytes but only got 11325. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 205914112 bytes but only got 11323. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 25852391584 bytes but only got 0. Skipping tag 39942
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 494469120 bytes but only got 0. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 645201920 bytes but only got 0. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 438501376 bytes but only got 0. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 205914112 bytes but only got 10687. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 205914112 bytes but only got 12987. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 205914112 bytes but only got 9833. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 515309568 bytes but only got 0. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 205914112 bytes but only got 11005. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 485228544 bytes but only got 0. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 205914112 bytes but only got 10546. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 196608 bytes but only got 0. Skipping tag 3
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 669450240 bytes but only got 0. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 205914112 bytes but only got 13357. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 541917184 bytes but only got 0. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 205914112 bytes but only got 11411. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 545849344 bytes but only got 0. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 205914112 bytes but only got 11471. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 19907780928 bytes but only got 0. Skipping tag 19017
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 440401920 bytes but only got 0. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 206045184 bytes but only got 9864. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 2776650663 bytes but only got 0. Skipping tag 26785
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 485621760 bytes but only got 0. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 205914112 bytes but only got 10552. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 479133696 bytes but only got 0. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 205914112 bytes but only got 10453. Skipping tag 4
#   "Skipping tag %s" % (size, len(data), tag))
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/PIL/TiffImagePlugin.py:692: UserWarning: Possibly corrupt EXIF data.  Expecting to read 14282151168 bytes but only got 0. Skipping tag 36966
#   "Skipping tag %s" % (size, len(data), tag))
# === 61.77135992050171  sec spent===

# %%
np.save('train_4.npy', train_data, allow_pickle=True, fix_imports=True)

le = LabelEncoder()
train_target = le.fit_transform(train['type'].values)
print(le.classes_) #in case not 1 to 3 order
np.save('train_target_4.npy', train_target, allow_pickle=True, fix_imports=True)
# Out:
# ['Type_1' 'Type_2' 'Type_3']

# %%
np.save('train_target.npy', b, allow_pickle=True, fix_imports=True)

# %%
test = glob.glob('/data/kaggle/test/*.jpg')
test = pd.DataFrame([[p.split('/')[4],p] for p in test], columns = ['image','path']) #[::20] #limit for Kaggle Demo
test_data = normalize_image_features(test['path'])
np.save('test.npy', test_data, allow_pickle=True, fix_imports=True)

# %%
test_id = test.image.values
np.save('test_id.npy', test_id, allow_pickle=True, fix_imports=True)

# %%
train = glob.glob('/data/kaggle/train/**/*.jpg') + glob.glob('/data/kaggle/additional/**/*.jpg')
train = pd.DataFrame([[p.split('/')[4],p.split('/')[5],p] for p in train], columns = ['type','image','path'])#[::5] #limit for Kaggle Demo
train = im_stats(train)
train = train[train['size'] != '0 0'].reset_index(drop=True) #remove bad images
train_data = normalize_image_features(train['path'])
np.save('train.npy', train_data, allow_pickle=True, fix_imports=True)

le = LabelEncoder()
train_target = le.fit_transform(train['type'].values)
print(le.classes_) #in case not 1 to 3 order
np.save('train_target.npy', train_target, allow_pickle=True, fix_imports=True)

test = glob.glob('/data/kaggle/test/*.jpg')
test = pd.DataFrame([[p.split('/')[4],p] for p in test], columns = ['image','path']) #[::20] #limit for Kaggle Demo
test_data = normalize_image_features(test['path'])
np.save('test.npy', test_data, allow_pickle=True, fix_imports=True)

test_id = test.image.values
np.save('test_id.npy', test_id, allow_pickle=True, fix_imports=True)

# %% [markdown]
# Start your neural network high performance engines
#
#  - I'll admit as you've no doubt noticed by now that I still don't know what I am doing with Neural Networks 'yet'.

# %%
from keras.wrappers.scikit_learn import KerasClassifier
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Flatten, Activation
from keras.layers.convolutional import Convolution2D, ZeroPadding2D, MaxPooling2D
from keras import optimizers
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from keras import backend as K
K.set_image_dim_ordering('th')
K.set_floatx('float32')

import pandas as pd
import numpy as np
np.random.seed(17)

train_data = np.load('train.npy')
train_target = np.load('train_target.npy')

x_train,x_val_train,y_train,y_val_train = train_test_split(train_data,train_target,test_size=0.4, random_state=17)

def create_model(opt_='adamax'):
    model = Sequential()
    model.add(Convolution2D(4, 3, 3, activation='relu', dim_ordering='th', input_shape=(3, 32, 32))) #use input_shape=(3, 64, 64)
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), dim_ordering='th'))
    model.add(Convolution2D(8, 3, 3, activation='relu', dim_ordering='th'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), dim_ordering='th'))
    model.add(Dropout(0.2))
    
    model.add(Flatten())
    model.add(Dense(12, activation='tanh'))
    model.add(Dropout(0.1))
    model.add(Dense(3, activation='softmax'))

    model.compile(optimizer=opt_, loss='sparse_categorical_crossentropy', metrics=['accuracy']) 
    return model

datagen = ImageDataGenerator(rotation_range=0.3, zoom_range=0.3)
datagen.fit(train_data)

model = create_model()
model.fit_generator(datagen.flow(x_train,y_train, batch_size=15, shuffle=True), nb_epoch=20, samples_per_epoch=len(x_train), verbose=20, validation_data=(x_val_train, y_val_train))

test_data = np.load('test.npy')
test_id = np.load('test_id.npy')

pred = model.predict_proba(test_data)
df = pd.DataFrame(pred, columns=['Type_1','Type_2','Type_3'])
df['image_name'] = test_id
df.to_csv('submission.csv', index=False)
# Out:
# Using TensorFlow backend.
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/ipykernel_launcher.py:23: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(4, (3, 3), data_format="channels_first", input_shape=(3, 32, 32..., activation="relu")`
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/ipykernel_launcher.py:24: UserWarning: Update your `MaxPooling2D` call to the Keras 2 API: `MaxPooling2D(data_format="channels_first", pool_size=(2, 2), strides=(2, 2))`
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/ipykernel_launcher.py:25: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(8, (3, 3), data_format="channels_first", activation="relu")`
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/ipykernel_launcher.py:26: UserWarning: Update your `MaxPooling2D` call to the Keras 2 API: `MaxPooling2D(data_format="channels_first", pool_size=(2, 2), strides=(2, 2))`
# /home/u3780/.conda/envs/test_env/lib/python3.5/site-packages/ipykernel_launcher.py:41: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras.pre..., steps_per_epoch=67, epochs=20, verbose=20, validation_data=(array([[[...)`
# Epoch 1/20
# Epoch 2/20
# Epoch 3/20
# Epoch 4/20
# Epoch 5/20
# Epoch 6/20
# Epoch 7/20
# Epoch 8/20
# Epoch 9/20
# Epoch 10/20
# Epoch 11/20
# Epoch 12/20
# Epoch 13/20
# Epoch 14/20
# Epoch 15/20
# Epoch 16/20
# Epoch 17/20
# Epoch 18/20
# Epoch 19/20
# Epoch 20/20
# 480/512 [===========================>..] - ETA: 0s

# %%
print(cpu_count())
